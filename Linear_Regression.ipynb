# %% [markdown]
# <a href="https://colab.research.google.com/github/kigit2017/Houe-price-prediction/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Regression ->
#  The ouput varaible to be preticted in continous in nature, e.g score, of a student , dimond price.
#
#  ### Classification ->
#   The output varaible to be predicted is catrgorical in nature e.g classifying incoming as spam or ham, yes or not, True & false , o & 1
#
#   ### supervised  learning ->
#   If the present tabular form, It contains past data with labels whihc are used for building models.
#
# ### Unsupervised learning - >
# It containes non-tabular data/ unordered data , no predefined labels to the past data.

# %% [markdown]
# ### Linear regression -
# Linear regression is a type of statitical analysis used to predict the relaIt assumes a linear relationship between 2 varaibles. It assumes a linear relationship between independent varaible and dependent variable, and aims to find the best-fitting line that describes the relationship.
#
# - The line is determined by minimizing the sum of the squared differences between the predicted values and the actual values.

# %% [markdown]
# ### A -> Simple linear regression -
# In this linear regression we have only one independent varaible and one dependent variables.
#
# y = mx + c ( Yi = B0 + B1X1)Yi = dependent variable, B0 = constant/intercept, Xi = independent varaible.

# %% [markdown]
# ### Cost Function -
# The cost function helps to work out the optimal values for B0 and B1, whihc provides the best fit line for the data points.
#
# - Mean squared error is a cost function whihc is used for finding the average of the all errors present in our data.
#
# ### Gradient descent ->
#  is used to minimize the cost functionof a model by adjusting its parameters.
#
#  Basic idea of the gradient descent is to compute the (partial derivatives)gradient of the cost function with respect to each parameters in the model.
# # New Section
#  Some steps involved in gradient descents are
#  - 1 -> Initialize parameters : Start by initializing the parameters of the model with some initila values.
#  - 2-> compute the cost : We will evaluate the cost function by f3eding the inout data to the model and comapring th predcited output with the actual output.
#  - 3-> Compute the Gradient -> Calculate the partial derivative of the cost function with respect to each parameter we will pass in our model. Gradient indicates the steepest ascent.
#  - 4-> Update parameters -> Adjust the parameters values by taking step in the opposite  direction of the gradient. This step is determined by a learning rate, whihc controls the size of the update at each iteration.
#  - 5-> Repeat -> Repeat step 2 to 4 until convergence or a predefiend number of iterations.
#  Convergence occurs when the cost function reaches a minimum or when the updates to the parameters become very small.

# %% [markdown]
# ## Evaluation Matrics for Linear regeression
# The strenght of lieanr regression model can be assessed using various evaluation metrics.
# ## Coefficient of Determination or R-squared (R2)
# R-Squared is a number that explains the amount of variation that is explained / captured by the developed model.
# It always ranges between 0 and 1.
# if the value of R-squares is higher , the better the model fits the data.
#
# R^2 = 1 - (RSS/TSS)
#
# ## RSS (Residual sum of Square) :
# is defiend as the sum of squares of the residuals for each data point in plot/area.It measures of the difference between the epcected and the actual oberved output.
#
# RSS = sigma(i=1,n)(yi -b0-b1xi)2
# b0=yhat-b1xhat
# b1=sigma(i)(xi-xhat)2/sima(i)yi(x-xhat) = sigma(i)(xi-xhat)/sigma(i)yi
# ## TSS( Total sum of square)
# is difined as the sum of errors of the data points from the mean of the response variable. TSS= sigma(y1-yhati)2

# %% [markdown]
# ## 2. Root Mean Square Error ?
# This the square root of  the variance of the residuals.It also specifies the abolute fit of the model to the data i.e how close the observed data point are to the predicted value.
#
# To make this estimate unbaised, one has to divide the sum of the sqaured eresiduals by the degree of freedom rather than the total number data points in the model.
#
#
# ## Assumptions of Linear Regression:
# ### 1. Linearity of residuals 🇰
#
# ### 2. Independence of residuals : T
# The error terms should not be dependent on one another (like -times series data where the next value is depedent on the previous one) . There should be no correlation between the residuals terms. The absesnce of this phenomenon is known as Autocorrelation.
#
# ### 3. Normal distribution of residuals 🇰
# The mean of residuals should follow a normal distribution  with a mean equal to zero or close to zero. This is done in order to check whether the selected line is actually the line of nbest fit or not.
# If the error terms are non-normally dsitributed, suggests that there are a few unusual data points that must be studied closely to make a better model.
#
# ### 4. The equal variance of residuals-
# The error terms must have cosntant variance. This is known homoscedacity.
#
# The presence of non-constant variance in the error term is reffered to as heteroscedasticity.
# non- constant variance arises in the presence of outliers or extreme leverage values.

# %% [markdown]
# ## Hypothesis in Linear regression
# Once we fitted a straight line on the data, you need to ask, <b>" Is this straight line a significatnt fit for the data? or "Is the beta cofficient explains the variance in the data plotted "</b> here we have idea of hypothesis testing on the beta cofficient.
#
# H0:B1 = 0
# Ha : B1 != 0
#
# To test this hypothessi we use a t-test, test statitics for the beta cofficient
#
# t = (m-mu)/(s/sqrt(n)
#
# ### Assesing the model fit
# ### 1. t statitics : It is used to determine the p-value, and hence, helps in determining whether the cofficient is significant or not.
# ### 2. F statistic : It is used to assess whether the overall model fit is significant or not. Generally, the higher the value of the F-statitics, the more significant a model turns out to be.

# %% [markdown]
# # Multiple Linear Regression
#
# This is the technique to uderstand the relationship between a single dependent variable and multiple independent variable.
#
# Y = B0 + B1X1 + B2X2 + B3X3 + ----- BnXn + e
#
# # Considerations of Multiple linear regression ⁉
#
# The assumption made in simple linear regression is same in MLR
# The addedd assumptions are:
#
# ### 1. Overfitting : Whe more and more variables are added to a model , the model may become far too complex and usually ends up memorizing the data ponis in training set. Thei phenomenon is known as the overfitting if a model.
# When you will find the training accuracy it will be higher but if you will find test accuracy it will be lesser.
#
# ### 2. Multicollinearity : It is phenomenon where a model with several idependent variables, may have some variables interrelated.
#
# ### 3. Fetaure selection:
# With more variables present n, selecting the optimal set of predictors from the pool of given feature becoms an import task for builiding better model.
#
# ### Multicollineraity -
# It makes difficukt to find our which variable is actually contributing towards the prediction of the response variable.it leads to colculdeincorrectly, the effects of a variable on the target variable.
# It will not effect the precision of the prediction, it is essential to properly detect and deal with the multicollineraity present in the model.
# Multicollineraity can be detected using the following methods.
# ### 1. pariwise Correlation : Checking the pariwise correltion between different pairs of idependent varaibles can throw useful insights in detecting multicollinearty.
# ### 2. Variance Inflation Factor (VIF) = VIF = 1/(1-R^2)
#
# pairwise is not always be useful, it is possible that just one variable mighth not be able to completely explain some other varaible but some of the vraibles combined could be able to able to define it.
# VIF  bascially explains the relationship of one independent variable with all the other independent variables. VIF
# VIF > 10 the values is definitely high and it should dropped. and if VIF = 5 then it may be valid but should be inspected 1st, VIF < 5 then it is cosidered a good VIF values.

# %% [markdown]
# ### Bias ->
#  It measures to determine how accurate is the model likely to be on future unseen data.Complex models, assuming theire is eniugh training data available, can do prediction accurately. Genreally linear algorithms have a high bias whihc makes them fasr to learn easier to understand but in general, are less flexible.
#
# if our dataset is complex this model will not perform well on the complex data.
#
# # Variance  :
# Variance is the sensitivity of the mdel towards training data, that is it quantifies how much model will reach when inout data is changed.
# Variance also used to measure the error in the data due to spreadness of the data.
# Moidel shoud not change too much from one training dataset to the next training datset, whihc will mean that the algorithm is good at picking out the hidden underlying patterns in inouts.
#
# ## Bias- variance trade-off ->
# The ultimate goal is to balance between bias and variance to acieve optimal model performance. Theis tradeoff implies that reducing bias often increase the variacne, and reducing the variance it will increase the bais.Key is to find the right level of complexity that minizes both bias and vairance.
# For that one we have 2 reularization techniques
# # L1 regularization
# # L2 - Regularization.
# If we want increase the model's comlexity, such as using a more sophisticated algorithm or increasing the number of deatrures , can help reduce the bias.

# %% [markdown]
# ## Overfitting : -
# When model learns eaach and every pattern and noise in the data to such extent that it affects the performance of the model on the unseen datset, it s reffered to as overfitting.
#
# When a model has low bias and high variance it ends up memprizing the data and causing overfitting .
#
# # How to solve the overfitting problems
# - cross-validation
# - If the training data is too small to train add more relevant and clean data,.
# - If the training data is too large, do some features selection and remove the unneccesary features.
# - Regularization.
#
# ## Undefitting :-
# Underfitting is not often discusses as overfitting . When the model fails to learn from the training datset and is also not able to generalize the test dataset, is reffered as undefitting.
# This type of problem can be vary easily detected by the performacne metrics.
#
# # Ways to prevent the undefitting problems
# - Increases the model complexity
# - incraes the number of features in the training data
# - Remove noise from the data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/content/train (3).csv')

# %%
# check the shape of our data

print('The shaoe of the dataset is', data.shape)
# Out:
# The shaoe of the dataset is (1460, 81)

# %%
# I want to check the 1st 5 values of our dataset
data.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
# We will filter out only the numerical datas
df = data.select_dtypes(include = ['float','int64'])
df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 38 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   OverallQual    1460 non-null   int64
#  5   OverallCond    1460 non-null   int64
#  6   YearBuilt      1460 non-null   int64
#  7   YearRemodAdd   1460 non-null   int64
#  8   MasVnrArea     1452 non-null   float64
#  9   BsmtFinSF1     1460 non-null   int64
#  10  BsmtFinSF2     1460 non-null   int64
#  11  BsmtUnfSF      1460 non-null   int64
#  12  TotalBsmtSF    1460 non-null   int64
#  13  1stFlrSF       1460 non-null   int64
#  14  2ndFlrSF       1460 non-null   int64
#  15  LowQualFinSF   1460 non-null   int64
#  16  GrLivArea      1460 non-null   int64
#  17  BsmtFullBath   1460 non-null   int64
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
miss_val=df.isna().sum()
miss_val
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
miss_val[miss_val>0].sort_values(ascending = False)
# Out:
# LotFrontage    259
# GarageYrBlt     81
# MasVnrArea       8
# dtype: int64

# %% [markdown]
# Fill NA columns with mean values from the column.

# %%
columns = ['LotFrontage','GarageYrBlt','MasVnrArea','BsmtHalfBath','BsmtFullBath','GarageArea','GarageCars','TotalBsmtSF',\
                'BsmtUnfSF','BsmtFinSF2','BsmtFinSF1']
for column in columns:
    df[column] = df[column].fillna(df[column].mean())

# %% [markdown]
# df_train is calculated with 1460 cols all the rows from  training .

# %%
df_train = df[:780]
df_test = df[780:]

df_train.shape
df_test.shape
# Out:
# (680, 38)

# %% [markdown]
# #Constructing correlation Matrix

# %%
data_corr = df_train.corr()
data_corr
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.063281    -0.080426 -0.005895     0.027324
# MSSubClass     0.063281    1.000000    -0.396791 -0.107007     0.037692
# LotFrontage   -0.080426   -0.396791     1.000000  0.261655     0.252243
# LotArea       -0.005895   -0.107007     0.261655  1.000000     0.101858
# OverallQual    0.027324    0.037692     0.252243  0.101858     1.000000
# OverallCond    0.023588   -0.040812    -0.098054 -0.004575    -0.079862
# YearBuilt      0.006135    0.019876     0.181234  0.017186     0.558648
# YearRemodAdd   0.038519    0.044735     0.090591  0.014950     0.547674
# MasVnrArea    -0.016670    0.025707     0.196449  0.079687     0.425495
# BsmtFinSF1     0.026137   -0.082435     0.135628  0.217224     0.242405
# BsmtFinSF2    -0.012573   -0.026027     0.041527  0.123122    -0.048497
# BsmtUnfSF     -0.025251   -0.135811     0.194916 -0.020837     0.312532
# ...

# %% [markdown]
# Al correlated fields of SalePrice > .6

# %%
data_corr=data_corr['SalePrice'][:-1]
data_corr[abs(data_corr)>0.6].sort_values(ascending=False)
# Out:
# OverallQual    0.798875
# GrLivArea      0.743660
# GarageCars     0.672238
# GarageArea     0.666504
# TotalBsmtSF    0.653298
# 1stFlrSF       0.634041
# Name: SalePrice, dtype: float64

# %% [markdown]
# corr between featurs >.6

# %%
df_train = df_train[['OverallQual','GrLivArea','GarageCars','GarageArea','TotalBsmtSF','1stFlrSF','SalePrice']]
df_test = df_test[['OverallQual','GrLivArea','GarageCars','GarageArea','TotalBsmtSF','1stFlrSF']]

# %% [markdown]
# Correlation data Heat Map, showing lighter color for low ranges,dark colors for higher,darkest being 1.

# %%
corr = df_train.corr()
sns.heatmap(corr,annot = True,square=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
train , val = train_test_split(df_train,test_size = 0.20)

# %%
train.shape
# Out:
# (624, 7)

# %%
val.shape
# Out:
# (156, 7)

# %%
train_x = train.drop(['SalePrice'],axis = 1)
train_y = train['SalePrice']

val_x = val.drop(['SalePrice'], axis = 1)
val_y = val['SalePrice']

# %%
from sklearn.linear_model import LinearRegression

model1 = LinearRegression()
model1.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
df_pred = model1.predict(val_x)

# %%
print(mean_absolute_error(df_pred,val_y))
print(mean_squared_error(df_pred,val_y))
print(r2_score(df_pred,val_y))
# Out:
# 25246.910099241457
# 1474246294.2593207
# 0.7182663821944595
